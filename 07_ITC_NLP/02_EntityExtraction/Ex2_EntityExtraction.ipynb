# %% [markdown]
# # Entity Extraction Workshop Exercise 2: Looking for Relations
#
# In this exercise we will use spaCy's entity extraction algorithm to find relations between different entities in the Brown corpus.
#
# ## Part 1: Basic entity extraction
#
# The Brown corpus is a well-known corpus of English developed at Brown Univeristy, containing text from many different sources. We will use entity extraction on a subset of the Brown corpus covering a few categories.
#
# We can use spaCy to find entities in a basic sentence as follows:

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
sample_sentence = "The White House is located in Washington D.C."
sample_doc = nlp(sample_sentence)
print([(ent.text, ent.label_) for ent in sample_doc.ents])
# Out:
# [('The White House', 'ORG'), ('Washington D.C.', 'GPE')]

# %% [markdown]
# To see what an entity label means:

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %% [markdown]
# And to display the entities in a document using displaCy:

# %%
from spacy import displacy
displacy.render(sample_doc, style='ent', jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Washington D.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>

# %% [markdown]
# Now let's load sentences from the Brown corpus for a few categories:

# %%
from nltk.corpus import brown
import nltk
nltk.download('brown')
sentences = brown.sents(categories = ['news', 'editorial', 'reviews'])
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/jeremybensoussan/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# **Questions:**
#   1. Use displaCy to display the entities in the first three sentences of this corpus. What are some entities that are tagged, and what do their entity labels means?
#   2. What are the five most common people mentioned in the corpus for these categories? What are the five most common buildings? (Hint: See [this page](https://spacy.io/usage/linguistic-features#section-named-entities) under "built-in entity types")

# %%
displacy.render(nlp(' '.join([' '.join(sentences[i]) for i in range(3)])), style='ent', jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5">The Fulton County Grand Jury said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  an investigation of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Atlanta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the City Executive Committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , which had over-all charge of the election , `` deserves the praise and thanks of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the City of Atlanta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  '' for the manner in which the election was conducted . The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     September-October
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  term jury had been charged by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Fulton Superior Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Judge
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Durwood Pye
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ivan Allen Jr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  .</div>

# %% [markdown]
# The entities tagged in this example are: <div class="alert alert-block alert-info">DATE, GPE, ORG, PERSON</div>

# %%
entities = ['DATE', 'GPE', 'ORG', 'PERSON']
print('\n'.join(['{}: {}'.format(entities[k], v) for k,v in enumerate(map(spacy.explain, entities))]))
# Out:
# DATE: Absolute or relative dates or periods
# GPE: Countries, cities, states
# ORG: Companies, agencies, institutions, etc.
# PERSON: People, including fictional

# %%
people_list = []
building_list = []

for sentence in sentences:
    for ent in nlp(' '.join(sentence)).ents:
        if ent.label_ == 'PERSON':
            people_list.append(ent.text)
        elif ent.label_ == 'FAC':
            building_list.append(ent.text)

# %%
from collections import Counter
print('Most common people are: {}'.format(Counter(people_list).most_common(5)))
print('Most common buildings are: {}'.format(Counter(building_list).most_common(5)))
# Out:
# Most common people are: [('Kennedy', 115), ('Khrushchev', 72), ('Maris', 34), ('Podger', 23), ('Eisenhower', 22)]
# Most common buildings are: [('Broadway', 16), ('the White House', 9), ('Capitol', 5), ('Pennsylvania Avenue', 4), ('Lewisohn Stadium', 4)]

# %% [markdown]
# ## Part 2: Finding relations

# %% [markdown]
# Now we will look at pairs of entities in sentences in the corpus and try to identify relations between them.
#
# **Questions**:
#   3. We would like to know where organizations are located. Try to find all occurences of organization-location where the organization (ORG) comes before the location (GPE) in the sentence, and the word "in" appears somewhere between them. Put this in a Pandas Dataframe with three columns: ORG (organization name), GPE (location name), and context (words in between the organization and location).  How many of these are there?
#
#   Hint: use entity.start and entity.end to get the starting and ending indices for an entity in the sentence.
#
#   4. How much does this data tell us about what organizations are located where? In what cases can we be more or less certain?
#
#   5. What is another example of a pair of entity labels and context word that would give us useful information? Try running your code to find this new relation.

# %%
import pandas as pd

org_loc_dict = {'ORG':[], 'GPE':[], 'context':[]}
for sentence in sentences:
    org_index = -1
    org = ''
    tokens = nlp(' '.join(sentence))
    for entity in tokens.ents:
        if org != '' and entity.label_ == 'GPE':
            context = ' '.join([tok.text for tok in tokens[org_index:entity.start]])
            if 'in' in context.lower().split(' '):
                org_loc_dict['ORG'].append(org)
                org_loc_dict['GPE'].append(entity.text)
                org_loc_dict['context'].append(context)
                org = ''
                org_index = -1
        elif entity.label_ == 'ORG':
            org = entity.text
            org_index = entity.end

# %%
org_locations = pd.DataFrame.from_dict(org_loc_dict, dtype='str')
org_locations
# Out:
#                                                   ORG                   GPE  \
# 0                        the State Welfare Department         Fulton County
# 1                                                 GOP            Blue Ridge
# 2                                         State Party              Savannah
# 3                                                 TEA         Dallas County
# 4                                                 ADC           Cook county
# 5                                         White House            Washington
# 6                                    Customary Senate                 Negro
# 7                                                NATO                Angola
# 8                                               State     the United States
# 9                                               State                Berlin
# 10                                   State Department                  Laos
# 11                  the Republican National Committee                  Laos
# 12                                              SEATO                  Laos
# 13                                    The White House     the United States
# 14                                             Sheets            New Jersey
# 15                                   the City Council              Brooklyn
# 16                          the Hunter College Campus                 Bronx
# 17                               the Democratic party           Mississippi
# 18                                             Martin            Washington
# 19                        Willamette University Young                 Salem
# 20             the Republican State Central Committee              Portland
# 21                                            Orioles           Kansas City
# 22                                               Kerr              New York
# 23                                    National A.A.U.              Columbus
# 24                                               Owls               Houston
# 25                                             Ramsey                Denver
# 26                              City of San Francisco                 Ogden
# 27                                             Giants             Milwaukee
# 28                                   New York Yankees            Cincinnati
# 29                   Rensselaer Polytechnic Institute                  Troy
# ..                                                ...                   ...
# 139                                          Cromwell           Westminster
# 140                      the Atomic Energy Commission             Las Vegas
# 141                                               PHS  the United States ''
# 142                     the World Council of Churches             New Delhi
# 143                    the Eisenhhower Administration                Berlin
# 144  the Catholic Association for International Peace            Washington
# 145                                              Duke              Browning
# 146                                                UN                Angola
# 147                                            Serene              Budapest
# 148                            the J. B. Speed Museum            Louisville
# 149                          the Academy of Fine Arts                Vienna
# 150                                 `` Louis Capet ''                 Texas
# 151                                     Confrontation                  U.S.
# 152                                     Confrontation               America
# 153                                     Watson-Watt's                    SR
# 154                                            Allied                Russia
# 155                                            Allied       North Russia ''
# 156             the Orchestral Society of Westchester     the County Center
# 157                                            Deemed          Philadelphia
# 158                                            Mijbil                  Iraq
# 159                             the Comedie Francaise              New York
# 160                                   the Flea Market                 Paris
# 161                                            Django               Belgium
# 162                                              WLIB               America
# 163                           `` Gloucester Harbor ''                 Sloan
# 164                                           Poconos          Pennsylvania
# 165            The Bayanihan Philippine Dance Company         San Francisco
# 166                         The Corinthian Yacht Club               Tiburon
# 167                    the Marquis Alfonso De Portago          Mille Miglia
# 168               Laboratory of Physiological Hygiene           Minneapolis
#
#                                                context
# 0    `` has seen fit to distribute these funds thro...
# 1      chairman , said a meeting held Tuesday night in
# 2    Chairman James W. Dorsey added that enthusiasm...
# 3    estimated there would be 182 scholastics to at...
# 4                                           program in
# 5                                              aids in
# 6    rules were ignored in order to speed approval ...
# 7    committee has been set up so that in the futur...
# 8    himself , in his first speech , gave some idea...
# 9    has also solemnly repeated a warning to the So...
# 10   officials explain , now is mainly interested i...
# 11   , that the Kennedy administration would be hel...
# 12   was steamed up and prepared contingency plans ...
# 13   is taking extraordinary steps to check the rap...
# 14   said , represents part of his program for elec...
# 15                        and Mr. Beame , who lives in
# 16                                              in the
# 17                                                  in
# 18                         , who has been in office in
# 19                       Republicans Thursday night in
# 20                                         Saturday in
# 21   once again performed at the plate in powderpuf...
# 22    , who set the world record earlier this month in
# 23                                             meet in
# 24                                  at Rice Stadium in
# 25   has a thing or two to mutter about himself , f...
# 26                                        , stopped in
# 27   who had been anemic with the bat in their wind...
# 28   won their 19th world series in a 5-game romp o...
# 29                                                  in
# ..                                                 ...
# 139                                                 in
# 140  , Dr. Glenn T. Seaborg , `` admitted '' to a n...
# 141  conceded that the new radioactive particles ``...
# 142                                        assembly in
# 143            , quite apart from the recent crises in
# 144                                                 in
# 145                                    's complaint in
# 146  against South African apartheid or Portuguese ...
# 147                 ( Mrs. Wilson ) , 23 , was born in
# 148                                                 in
# 149                                                 in
# 150                         , John Tower 's victory in
# 151  '' should fortify us all , whether in Southeas...
# 152  '' was certainly direct in its appeal to those...
# 153                                         remarks in
# 154            governments about what was happening in
# 155                                    intervention in
# 156                                                 in
# 157  too static when it was first heard in `` Lady ...
# 158  , of whom there are a fine series of photograp...
# 159        are the most important recent events in the
# 160                                                 in
# 161          , who was born Jean Baptiste Reinhardt in
# 162  boasts `` more community service programs than...
# 163  in 1915 ) , the human element was the compelli...
# 164                                                 in
# 165  , with music and dances that depict the many f...
# 166                                                 in
# 167     , the Spanish nobleman who died driving in the
# 168      , under the university 's football stadium in
#
# [169 rows x 3 columns]

# %% [markdown]
# #### 4. The context column helps a lot in understanding the link between the Organization and their locations.
# The organization/places tuples that have a context such as 'in' or 'in the' are the most reliable to be in that location.
#
# After those, I would say the organizations with a context where the last word is 'in' are likely to be in that location.
#
# Finally, the places for which the word 'in' in located anywhere but in the end of the context are more prone to confusion.

# %%
author_dict = {'author':[], 'artpiece':[], 'context':[]}
for sentence in sentences:
    author_index = -1
    author = ''
    tokens = nlp(' '.join(sentence))
    for entity in tokens.ents:
        if author != '' and entity.label_ == 'WORK_OF_ART':
            context = ' '.join([tok.text for tok in tokens[author_index:entity.start]])
            if 'of' in context.lower().split(' ') or 'from' in context.lower().split(' '):
                author_dict['author'].append(author)
                author_dict['artpiece'].append(entity.text)
                author_dict['context'].append(context)
                author = ''
                author_index = -1
        elif entity.label_ == 'PERSON':
            author = entity.text
            author_index = entity.end

# %%
authors = pd.DataFrame.from_dict(author_dict, dtype='str')
authors
# Out:
#                  author                                           artpiece  \
# 0       T. F. Zimmerman                                              Bible
# 1       Alva W. Vernava                                          Maple Ave
# 2           Monte Carlo                                Francesca Da Rimini
# 3               Brevard                                            Gallery
# 4       Richard Preston  the Governors Conference on Industrial Develop...
# 5          Geroge Bragg                                 `` Stabat Mater ''
# 6             Rudy Bond                               `` Little Tin Box ''
# 7                 Brown                           `` Where The Boys Are ''
# 8           Owen Wister                                `` The Virginian ''
# 9      Frederick Fuller                                    East Meets West
# 10         Julie Wilson                             `` Hard-Hearted Hannah
# 11         Murray Louis                                             Signal
# 12          Wallenstein                                         Leonore ''
# 13     Dorothy Loudon's                          At The Roxy Music Hall ''
# 14   Alexandre Livshitz                                        Taras Bulba
# 15  Alexandre Pavlovsky                                     `` Le Cygne ''
#
#                                               context
# 0   , general superintendent , commented , `` The ...
# 1                                        , 21 , of 23
# 2   , will present a program of four ballets inclu...
# 3                          group of 85 arrived at the
# 4   , executive director of the New Hampshire Stat...
# 5   , the twenty - six boys made some lovely sound...
# 6         and his band of tuneful ward - heelers made
# 7   senior , while two Yalies are cast as virtual ...
# 8                                         , author of
# 9   , baritone , presented a program of folksongs ...
# 10  , a vigorous vocalist without many wild twists...
# 11  and his dance company appeared at the Henry St...
# 12  , who will lead all of the concerts in the cyc...
# 13              raucous listing of the attractions ``
# 14  repeated a fantastic technical bit from the cl...
# 15                , and a lovely version of Fokine 's

# %%
nationalities_dict = {'person':[], 'nationality':[], 'context':[]}
for sentence in sentences:
    person_index = -1
    person = ''
    tokens = nlp(' '.join(sentence))
    for entity in tokens.ents:
        if person != '' and entity.label_ == 'NORP':
            context = ' '.join([tok.text for tok in tokens[person_index:entity.start]])
            if 'of' in context.lower().split(' ') or 'from' in context.lower().split(' '):
                nationalities_dict['person'].append(person)
                nationalities_dict['nationality'].append(entity.text)
                nationalities_dict['context'].append(context)
                person = ''
                person_index = -1
        elif entity.label_ == 'PERSON':
            person = entity.text
            person_index = entity.end

# %%
nationalities = pd.DataFrame.from_dict(nationalities_dict, dtype='str')
nationalities
# Out:
#                  person         nationality  \
# 0        J. M. Cheshire             Griffin
# 1               Kennedy           Americans
# 2               Kennedy           Communist
# 3                Castro           Communist
# 4       Souvanna Phouma          Communists
# 5      James J. Sheeran          Republican
# 6                Wagner          Democratic
# 7       Souvanna Phouma           Communist
# 8            Pathet Lao           Communist
# 9              Anderson               Cuban
# 10            M. Kegham          Communists
# 11             Cranston            American
# 12      Alva W. Vernava             Vernava
# 13               Hester            American
# 14           Allen Huff                Loan
# 15         Edward Weeks             Russian
# 16    C. Wheeler Barnes            Scottish
# 17           Khrushchev           Communist
# 18             Thompson              Soviet
# 19         Fidel Castro               Cuban
# 20      Hubert Humphrey  Southern Democrats
# 21              Richard          Democratic
# 22              Kimpton            Idealist
# 23        Joseph Mobutu           Congolese
# 24      Walter Ulbricht              Soviet
# 25                 Rusk          Australian
# 26           Khrushchev             Indians
# 27         Harold Colee    South Floridians
# 28       Walter Reuther            American
# 29              Freeman              Soviet
# ..                  ...                 ...
# 44             Crossman         East German
# 45          Rockefeller              Soviet
# 46                 John           Christian
# 47              Marlene              Arabic
# 48              Schiele            Danubian
# 49                Lenin           Communist
# 50           Khrushchev              Soviet
# 51           Khrushchev              German
# 52   Marshal Malinovsky             Chinese
# 53           Khrushchev              Soviet
# 54      Richard Lauchli            Browning
# 55  First Viscount Slim             British
# 56         Marshal Slim            Japanese
# 57      George Kennan's             Tsarism
# 58           Alger Hiss              Soviet
# 59               Kennan            American
# 60         Grace Carney               Irish
# 61   Claude Jannequin's              French
# 62               Herman            American
# 63        Gavin Maxwell            Scottish
# 64               Phedre               Greek
# 65            Lily Pons              French
# 66               Ronnie             British
# 67               Sansom           Hungarian
# 68       William Sansom           Norwegian
# 69      Andrea Palladio             Vicenza
# 70      Andrea Palladio            Southern
# 71    Richard Yardumian             Swedish
# 72       Miss McCullers            American
# 73      Hurricane Carla             Mexican
#
#                                               context
# 0                                                  of
# 1   today proposed a mammoth new medical care prog...
# 2   administration would be held responsible if th...
# 3                                     regime from the
# 4                  , whom it felt was too trusting of
# 5                            of West Orange , for the
# 6                           has the confidence of the
# 7   , leader of the nation 's neutralists and reco...
# 8   rebel attacks had been launched , heavily supp...
# 9   , a Seattle ex - marine and Havana businessman...
# 10  -- the name is a pseudynom -- was a teacher in...
# 11  and stole an estimated $ 3,675 worth of furs ,...
# 12  , 21 , of 23 Maple Ave . , North Providence , ...
# 13  , also one of the youngest men ever to head a ...
# 14  , 41 , of 1630 Lake Av . , Wilmette , was arre...
# 15                    moderates a round table of four
# 16                            of Denver , head of the
# 17  was also concerned about a possible spread of ...
# 18                      reported from Moscow that the
# 19  suddenly confronted the U.S. with a blunt and ...
# 20  to Massachusetts ' Republican Leverett Saltons...
# 21  until his death last March , got a brotherly b...
# 22  , now a Standard Oil ( Indiana ) executive , t...
# 23                            , chief of staff of the
# 24                                      , by grace of
# 25  , en route to Bangkok , doubtless is trying to...
# 26  the idea that he will not really get much enjo...
# 27                  of Jacksonville and including two
# 28  , leader of the industrial union faction of th...
# 29  said that in many of the countries he visited ...
# ..                                                ...
# 44  , is that `` The closing off of East Berlin wi...
# 45  said that `` to assure the sufficiency of our ...
# 46  sees the renewal and purification of the Churc...
# 47  ( surname : Adamo ) , 25 , a Brazilian divorce...
# 48          lived most of his childhood in the drowsy
# 49  `` full communism '' was still a very distant ...
# 50  , together with the everlasting attacks on Mol...
# 51  , for all his bombastic prophecies about the i...
# 52  , who was blowing hot and cold , exalting peac...
# 53                 ( and , with him , the bulk of the
# 54  of Collinsville , Ill. , and seized four opera...
# 55  , former Governor General of Australia , was t...
# 56                is more impressed by the courage of
# 57  account of relations between Russia and the We...
# 58  , subsequently convicted of perjury in denying...
# 59  , who has recently abandoned authorship for a ...
# 60  and Sibly Bowan who may be right off the shelf...
# 61                vocal description of a battle ( the
# 62  has managed to mix musical ideas drawn from Is...
# 63  is just that -- a haunting , warmly personal c...
# 64  '' was done in 17th century setting , instead ...
# 65       led the list of celebrities in an evening of
# 66  ( we never do see him ) and has been subjected...
# 67  writes of foreign parts with a dedication to d...
# 68  writes only about Europe in this book and freq...
# 69                   himself that dot the environs of
# 70  still smiles from behind many an old rocking c...
# 71  and a brief excerpt from a new `` space '' ope...
# 72  uses her poet 's instinct and storyteller 's s...
# 73  damaged 70 % of the marinas in the Galveston -...
#
# [74 rows x 3 columns]
